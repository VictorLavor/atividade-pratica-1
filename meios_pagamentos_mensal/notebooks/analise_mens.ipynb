# %%
import os
import pandas as pd
import json
import re

# %% [markdown]
# Visualisando os dados em JSON

# %%
caminho = r"C:\Users\victo\OneDrive\Documentos\Faculdade Senac\4 Periodo\Big Data\API\meios_pagamentos_mensal\data\meios_pagamentos.json"
df = pd.read_json(caminho)
print(df.head())
# Out:
#                                       @odata.context  \
# 0  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 1  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 2  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 3  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 4  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
#
#                                                value
# 0  {'AnoMes': '202507', 'quantidadePix': 6698196....
# 1  {'AnoMes': '202506', 'quantidadePix': 6464330....
# 2  {'AnoMes': '202505', 'quantidadePix': 6643181....
# 3  {'AnoMes': '202504', 'quantidadePix': 6278102....
# 4  {'AnoMes': '202503', 'quantidadePix': 6249384....

# %% [markdown]
# Transforme o arquivo json em dataframe

# %%
# Caminho para o JSON bruto
caminho_json = r"C:\Users\victo\OneDrive\Documentos\Faculdade Senac\4 Periodo\Big Data\API\meios_pagamentos_mensal\data\meios_pagamentos.json"

# Ler o JSON e carregar os dados da chave 'value'
with open(caminho_json, "r", encoding="utf-8") as f:
    dados = json.load(f)

# Transformar o JSON em DataFrame
df = pd.DataFrame(dados["value"])

# Exibir as 5 primeiras linhas para conferência
df.head()
# Out:
#    AnoMes  quantidadePix    valorPix  quantidadeTED    valorTED  \
# 0  202507     6698196.91  3497412.52       67192.89  3915166.65
# 1  202506     6464330.71  2869832.97       62477.43  3742911.28
# 2  202505     6643181.01  2822151.77       64178.98  3799492.18
# 3  202504     6278102.30  2676807.81       64449.00  3850452.25
# 4  202503     6249384.72  2570468.46       61294.83  3683199.49
#
#    quantidadeCheque  quantidadeBoleto
# 0           8507.87         353819.55
# 1           8217.12         338127.37
# 2           8406.19         340006.42
# 3           8454.24         341624.79
# 4           8808.83         340788.00

# %% [markdown]
# Extrair os dados do JSON e tratar para CSV

# %%
# === Caminhos ===
caminho_json = r"C:\Users\victo\OneDrive\Documentos\Faculdade Senac\4 Periodo\Big Data\API\meios_pagamentos_mensal\data\meios_pagamentos.json"
pasta_tratados = os.path.join(os.path.dirname(caminho_json), "..", "tratados")
os.makedirs(pasta_tratados, exist_ok=True)
caminho_csv = os.path.join(pasta_tratados, "meios_pagamentos_tratado.csv")

# === Ler JSON e acessar a chave 'value' ===
with open(caminho_json, "r", encoding="utf-8") as f:
    dados = json.load(f)

df = pd.DataFrame(dados["value"])  # pega somente os dados

# === Converter coluna AnoMes para datetime e ordenar ===
df["AnoMes"] = pd.to_datetime(df["AnoMes"].astype(str), format="%Y%m", errors="coerce")
df["AnoMes"] = df["AnoMes"].dt.strftime("%Y-%m")
df = df.sort_values("AnoMes")

# === Garantir que colunas numéricas sejam números ===
def to_num(x):
    if pd.isna(x): 
        return x
    s = str(x).strip()
    s = s.replace(".", "").replace(",", ".")          # remove separador de milhar, troca decimal vírgula por ponto
    s = re.sub(r"[^0-9\.\-]", "", s)                  # remove símbolos extras
    try:
        return float(s)
    except:
        return pd.NA

for col in df.columns:
    low = col.lower()
    if low.startswith("quantidade") or low.startswith("valor"):
        df[col] = df[col].map(to_num)

# === Salvar CSV tratado ===
df.to_csv(caminho_csv, index=False, encoding="utf-8")
print("✅ CSV tratado salvo com sucesso!")
print("📂 Local:", caminho_csv)
df.head()
# Out:
# ✅ CSV tratado salvo com sucesso!
# 📂 Local: C:\Users\victo\OneDrive\Documentos\Faculdade Senac\4 Periodo\Big Data\API\meios_pagamentos_mensal\data\..\tratados\meios_pagamentos_tratado.csv
#      AnoMes  quantidadePix     valorPix  quantidadeTED     valorTED  \
# 19  2023-12    478375909.0   19198360.0      8020226.0  362975888.0
# 18  2024-01    435007685.0  180438292.0      7034325.0  333734485.0
# 17  2024-02    434491769.0  170393555.0      6580587.0  298122645.0
# 16  2024-03    488046105.0  192098695.0      6756505.0  333305427.0
# 15  2024-04    490046649.0  206261468.0      7064715.0  365260648.0
#
#     quantidadeCheque  quantidadeBoleto
# 19         1124191.0        33755205.0
# 18         1191912.0        36355032.0
# 17         1037338.0        33226947.0
# 16         1012246.0        33643546.0
# 15         1117922.0        36163328.0

# %% [markdown]
# Verificando valores nulos e exibindo os tipos de dados em df:

# %%
print("Contagem de Valores NULOS:")
print(df.isnull().sum())

print("\nTipos de Dados:")
print(df.dtypes)
# Out:
# Contagem de Valores NULOS:
# AnoMes              0
# quantidadePix       0
# valorPix            0
# quantidadeTED       0
# valorTED            0
# quantidadeCheque    0
# quantidadeBoleto    0
# dtype: int64
#
# Tipos de Dados:
# AnoMes               object
# quantidadePix       float64
# valorPix            float64
# quantidadeTED       float64
# valorTED            float64
# quantidadeCheque    float64
# quantidadeBoleto    float64
# dtype: object

# %% [markdown]
# # Renomeando colunas

# %%
dados_df = df.rename(columns={"quantidadePix": "qtdPix","quantidadeTED": "qntTED","quantidadeCheque":"qntCheque","quantidadeBoleto":"qntBoleto"})

print(dados_df)
# Out:
#      AnoMes       qtdPix     valorPix     qntTED     valorTED  qntCheque  \
# 19  2023-12  478375909.0   19198360.0  8020226.0  362975888.0  1124191.0
# 18  2024-01  435007685.0  180438292.0  7034325.0  333734485.0  1191912.0
# 17  2024-02  434491769.0  170393555.0  6580587.0  298122645.0  1037338.0
# 16  2024-03  488046105.0  192098695.0  6756505.0  333305427.0  1012246.0
# 15  2024-04  490046649.0  206261468.0  7064715.0  365260648.0  1117922.0
# 14  2024-05  520420373.0  210333384.0  6902311.0  348203697.0  1046785.0
# 13  2024-06   52522207.0  211834752.0  6359932.0  352791228.0   964276.0
# 12  2024-07  539253101.0  233771913.0  6965715.0  382894882.0   109428.0
# 11  2024-08  563907365.0  232582432.0  6758113.0  362102265.0  1000939.0
# 10  2024-09  551482262.0  231288602.0  6615598.0  373024621.0   997894.0
# 9   2024-10  571963701.0  247708505.0  6859051.0  388578981.0  1020217.0
# 8   2024-11  580199659.0  245745329.0   658159.0   35037135.0   901891.0
# 7   2024-12  643920129.0  277958711.0  7661111.0  425776235.0   961644.0
# 6   2025-01  568252069.0  247030793.0  6223213.0  370572169.0   919915.0
# 5   2025-02  560813227.0  243217367.0  6194908.0  337876496.0   835017.0
# 4   2025-03  624938472.0  257046846.0  6129483.0  368319949.0   880883.0
# 3   2025-04   62781023.0  267680781.0   644490.0  385045225.0   845424.0
# 2   2025-05  664318101.0  282215177.0  6417898.0  379949218.0   840619.0
# 1   2025-06  646433071.0  286983297.0  6247743.0  374291128.0   821712.0
# 0   2025-07  669819691.0  349741252.0  6719289.0  391516665.0   850787.0
#
#      qntBoleto
# 19  33755205.0
# 18  36355032.0
# 17  33226947.0
# 16  33643546.0
# 15  36163328.0
# 14  34918092.0
# 13  32775493.0
# 12  36648415.0
# 11  34392499.0
# 10  34469846.0
# 9   36219291.0
# 8   33250115.0
# 7   36104281.0
# 6   33895259.0
# 5    3244817.0
# 4    3407880.0
# 3   34162479.0
# 2   34000642.0
# 1   33812737.0
# 0   35381955.0

# %% [markdown]
# Evolução Mensal do Pix x TED x Cheque x Boleto

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
df.rename(columns={
    "quantidadePix": "qntPix",
    "quantidadeTED": "qntTED",
    "quantidadeCheque":"qntCheque",
    "quantidadeBoleto":"qntBoleto"
}, inplace=True)
plt.plot(df["AnoMes"], df["qntPix"], marker="o", label="Pix")
plt.plot(df["AnoMes"], df["qntTED"], marker="o", label="TED")
plt.plot(df["AnoMes"], df["qntCheque"], marker="o", label="Cheque")
plt.plot(df["AnoMes"], df["qntBoleto"], marker="o", label="Boleto")
plt.title("Evolução Mensal – Quantidade de Transações (Pix x TED x Cheque x Boleto)")
plt.xlabel("Mês")
plt.ylabel("Quantidade")
plt.grid()
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Comparativo total entre os meios de pagamento

# %%
cols_qtd = ["qntPix", "qntTED", "qntBoleto", "qntCheque"]
totais = df[cols_qtd].sum(numeric_only=True)

plt.figure(figsize=(8,5))
totais.plot(kind="bar", color=["#0077b6", "#ff7f51", "#90be6d", "#f9c74f"])
plt.title("Volume Total de Transações por Meio de Pagamento")
plt.ylabel("Quantidade Total")
plt.xlabel("Meio de Pagamento")
plt.grid(axis="y")
plt.tight_layout()
plt.show()

# %% [markdown]
# Percentual total por meio de pagamento

# %%
plt.figure(figsize=(7,7))
totais.plot(kind="pie", autopct="%1.1f%%", startangle=90, ylabel="")
plt.title("Participação Percentual por Meio de Pagamento")
plt.tight_layout()
plt.show()
